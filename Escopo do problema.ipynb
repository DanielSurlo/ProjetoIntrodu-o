# %% [markdown]
# ## Escopo do problema:
#
# Controle de entrada e saída de dispositvos em empresas.
#
# #### Exemplos de dispositivos que podem abranger o sistema:
#
# * Tablets.
# * Notebooks.
# * Celulares.
